# %% [markdown]
# # Arthematic Operators

# %% [markdown]
# ### program to add two numbers

# %%
num1=int(input("Enter first number " ))
num2=int(input("Enter second number" ))
sum=num1+num2
print(sum)
# Out:
# 12

# %% [markdown]
# ### program to find remainder

# %%
x=int(input("Enter numerator "))
y=int(input("Enter denumerator "))
rem=x%y
print(rem)
# Out:
# 4

# %% [markdown]
# ### calculating square

# %%
x=int(input("Enter a number "))
y=2
square=x**y
print(square)
# Out:
# 36

# %% [markdown]
# # Assignment operators

# %%
x=3
x=x*5
print(x)
# Out:
# 15

# %%
x=int(input("enter a number"))
y=x*2
print(y)
# Out:
# 14

# %%
x=int(input("enter a number"))
x-=10
print(x)
# Out:
# 2

# %% [markdown]
# # Comparison Operators

# %%
x=int(input("Enter a number"))
y=int(input("Enter another number"))
print(x==y)
# Out:
# False

# %%
x=int(input("Enter a number"))
y=int(input("Enter another number"))
print(x>y)
# Out:
# True

# %%
x=int(input("Enter a number"))
y=int(input("Enter another number"))
print(x>=y)
print(x<=y)
# Out:
# True
# False

# %% [markdown]
# # Logical Operators

# %%
x=int(input("Enter a number"))
y=int(input("Enter another number"))
print((x>5)&(x<20))
# Out:
# True

# %%
x=int(input("Enter a number"))
y=int(input("Enter another number"))
print((x<10)|(x>50))
# Out:
# True

# %%
x=input("Enter condition")
y=input("Enter condition")
print(not x)
print(not y)
# Out:
# False
# False

# %% [markdown]
# # Membership Operator

# %%
x={2,4,6,8,9,5}
y=int(input("Enter amnumber"))
print(y in x)
# Out:
# True

# %%
x={"do","have","you","are"}
y=input("Enter your word")
print(y in x)
# Out:
# True

# %%
x={1,3,5,7,9}
y=int(input("Enter amnumber"))
print(y not in x)
# Out:
# False
